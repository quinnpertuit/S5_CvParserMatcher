# %% [markdown]
# # DataBase PipeLine

# %%
# http://api.mongodb.com/python/current/tutorial.html
import pymongo
from pymongo import MongoClient
import pprint

# %%
client = MongoClient('mongodb+srv://user_imt:2020@s5resumesdb-ppukj.azure.mongodb.net/test')
client
# Out:
# MongoClient(host=['s5resumesdb-shard-00-01-ppukj.azure.mongodb.net:27017', 's5resumesdb-shard-00-00-ppukj.azure.mongodb.net:27017', 's5resumesdb-shard-00-02-ppukj.azure.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='S5ResumesDB-shard-0', ssl=True)

# %%
my_db = client["db"]

# %%
my_db.list_collection_names()
# Out:
# ['jobs_sovren', 'resumes_sovren', 'resumes']

# %%
collection=my_db["jobs_sovren"]

# %%
collection.count()
# Out:
# /Users/ricardorodriguez/anaconda3/envs/skills-ml/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 11

# %%
pprint.pprint(collection.find()[1])
# Out:
# {'SovrenData': {'@xml:lang': 'en',
#                 'CurrentJobIsMgmt': 'false',
#                 'CurrentLocation': {'CountryCode': 'JP',
#                                     'Municipality': 'Tokyo'},
#                 'DigitalSignature': 'JoP///////8=',
#                 'DocumentLanguage': 'en',
#                 'Education': {'Degree': [{'DegreeName': "master's degree in "
#                                                         'mathematics and '
#                                                         'Statistics',
#                                           'DegreeType': 'masters'}]},
#                 'EmployerNames': {'MainEmployerName': 'WHAT WE ARE LOOKING '
#                                                       'FOR'},
#                 'ExecutiveType': 'NONE',
#                 'HighestManagementScore': '0',
#                 'JobTitles': {'JobTitle': ['member of the data science team',
#                                            'member'],
#                               'MainJobTitle': 'member of the data science '
#                                               'team, and working alongside our '
#                                               'technical experts'},
#                 'LanguageCodes': {'LanguageCode': ['fr', 'en']},
#                 'ManagementLevel': 'none',
#                 'ParserConfigurationString': 'Coverage.PersonalAttributes = '
#                                              'True; Coverage.Training = True; '
#                                              'Culture.CountryCodeForUnitedKingdomIsUK '
#                                              '= False; '
#                                              'Culture.DefaultCountryCode = US; '
#                                              'Culture.Language = English; '
#                                              'Culture.PreferEnglishVersionIfTwoLanguagesInDocument '
#                                              '= False; Data.UserDefinedParsing '
#                                              '= False; '
#                                              'OutputFormat.AssumeCompanyNameFromPrecedingJob '
#                                              '= False; '
#                                              'OutputFormat.ContactMethod.PackStyle '
#                                              '= Split; '
#                                              'OutputFormat.DateOutputStyle = '
#                                              'ExplicitlyKnownDateInfoOnly; '
#                                              'OutputFormat.NestJobsBasedOnDateRanges '
#                                              '= True; '
#                                              'OutputFormat.NormalizeRegions = '
#                                              'False; OutputFormat.SkillsStyle '
#                                              '= Default; '
#                                              'OutputFormat.StripParsedDataFromPositionHistoryDescription '
#                                              '= True; '
#                                              'OutputFormat.TelcomNumber.Style '
#                                              '= Raw; OutputFormat.XmlFormat = '
#                                              'HrXmlResume25',
#                 'RequiredDegree': 'masters',
#                 'RevisionDate': '2020-03-08',
#                 'SkillsTaxonomyOutput': [{'@name': 'Sovren',
#                                           'Taxonomy': [{'@id': '10',
#                                                         '@name': 'Information '
#                                                                  'Technology',
#                                                         '@percentOfOverall': 45.0,
#                                                         'Subtaxonomy': [{'@id': '553',
#                                                                          '@name': 'Big '
#                                                                                   'Data',
#                                                                          '@percentOfOverall': 15.0,
#                                                                          '@percentOfParentTaxonomy': 33.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '5530958',
#                                                                                     '@name': 'DATA '
#                                                                                              'SCIENCE',
#                                                                                     '@required': False},
#                                                                                    {'@existsInText': True,
#                                                                                     '@id': '5531016',
#                                                                                     '@name': 'MACHINE '
#                                                                                              'LEARNING',
#                                                                                     '@required': True},
#                                                                                    {'@existsInText': False,
#                                                                                     '@id': '5531029',
#                                                                                     '@name': 'NATURAL '
#                                                                                              'LANGUAGE '
#                                                                                              'PROCESSING',
#                                                                                     '@required': False,
#                                                                                     'ChildSkill': [{'@existsInText': True,
#                                                                                                     '@id': '5531030',
#                                                                                                     '@name': 'NLP',
#                                                                                                     '@required': True}]}]},
#                                                                         {'@id': '720',
#                                                                          '@name': 'Machine '
#                                                                                   'Learning',
#                                                                          '@percentOfOverall': 6.0,
#                                                                          '@percentOfParentTaxonomy': 13.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '7200001',
#                                                                                     '@name': 'DATA '
#                                                                                              'SCIENCE',
#                                                                                     '@required': False},
#                                                                                    {'@existsInText': True,
#                                                                                     '@id': '7200149',
#                                                                                     '@name': 'MACHINE '
#                                                                                              'LEARNING',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '351',
#                                                                          '@name': 'Multimedia',
#                                                                          '@percentOfOverall': 6.0,
#                                                                          '@percentOfParentTaxonomy': 13.0,
#                                                                          'Skill': [{'@existsInText': False,
#                                                                                     '@id': '351001',
#                                                                                     '@name': 'PERKS '
#                                                                                              'ENTERPRISE',
#                                                                                     '@required': False,
#                                                                                     'ChildSkill': [{'@existsInText': True,
#                                                                                                     '@id': '35100101',
#                                                                                                     '@name': 'PERKS',
#                                                                                                     '@required': False}]}]},
#                                                                         {'@id': '204',
#                                                                          '@name': 'Programming',
#                                                                          '@percentOfOverall': 6.0,
#                                                                          '@percentOfParentTaxonomy': 13.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '023329',
#                                                                                     '@name': 'OBJECT-ORIENTED',
#                                                                                     '@required': False,
#                                                                                     'ChildSkill': [{'@existsInText': True,
#                                                                                                     '@id': '003631',
#                                                                                                     '@name': 'OBJECT-ORIENTED '
#                                                                                                              'PROGRAMMING',
#                                                                                                     '@required': False}]}]},
#                                                                         {'@id': '338',
#                                                                          '@name': 'Security',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 7.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '3380002',
#                                                                                     '@name': 'MACHINE '
#                                                                                              'LEARNING',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '253',
#                                                                          '@name': 'Protocols '
#                                                                                   'and '
#                                                                                   'Standards',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 7.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '081190',
#                                                                                     '@name': 'REAL-TIME',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '340',
#                                                                          '@name': 'Embedded '
#                                                                                   'and '
#                                                                                   'Realtime',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 7.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '081186',
#                                                                                     '@name': 'REAL-TIME',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '193',
#                                                                          '@name': 'Database',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 7.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '014973',
#                                                                                     '@name': 'DATA '
#                                                                                              'CLEANING',
#                                                                                     '@required': True}]}]},
#                                                        {'@id': '5',
#                                                         '@name': 'Engineering',
#                                                         '@percentOfOverall': 15.0,
#                                                         'Subtaxonomy': [{'@id': '307',
#                                                                          '@name': 'General '
#                                                                                   'Engineering',
#                                                                          '@percentOfOverall': 6.0,
#                                                                          '@percentOfParentTaxonomy': 40.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '080478',
#                                                                                     '@name': 'CALIBRATION',
#                                                                                     '@required': True},
#                                                                                    {'@existsInText': True,
#                                                                                     '@id': '080509',
#                                                                                     '@name': 'REAL-TIME',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '144',
#                                                                          '@name': 'Computer '
#                                                                                   'Hardware',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 20.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '080770',
#                                                                                     '@name': 'REAL-TIME',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '264',
#                                                                          '@name': 'Techniques',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 20.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '080637',
#                                                                                     '@name': 'CALIBRATION',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '309',
#                                                                          '@name': 'Stress '
#                                                                                   'Analysis '
#                                                                                   'and '
#                                                                                   'Testing',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 20.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '080308',
#                                                                                     '@name': 'CALIBRATION',
#                                                                                     '@required': True}]}]},
#                                                        {'@id': '14',
#                                                         '@name': 'Marketing',
#                                                         '@percentOfOverall': 9.0,
#                                                         'Subtaxonomy': [{'@id': '588',
#                                                                          '@name': 'Data '
#                                                                                   '& '
#                                                                                   'Analytics',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 33.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '1400075',
#                                                                                     '@name': 'DATA '
#                                                                                              'SCIENCE',
#                                                                                     '@required': False}]},
#                                                                         {'@id': '585',
#                                                                          '@name': 'Product',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 33.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '1400022',
#                                                                                     '@name': 'PRODUCT '
#                                                                                              'DEVELOPMENT',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '227',
#                                                                          '@name': 'Brand '
#                                                                                   'Management',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 33.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '005612',
#                                                                                     '@name': 'PRODUCT '
#                                                                                              'DEVELOPMENT',
#                                                                                     '@required': True}]}]},
#                                                        {'@id': '19',
#                                                         '@name': 'Insurance',
#                                                         '@percentOfOverall': 9.0,
#                                                         'Subtaxonomy': [{'@id': '416',
#                                                                          '@name': 'Auto',
#                                                                          '@percentOfOverall': 6.0,
#                                                                          '@percentOfParentTaxonomy': 67.0,
#                                                                          'Skill': [{'@existsInText': False,
#                                                                                     '@id': '024485',
#                                                                                     '@name': 'AUTO '
#                                                                                              'INSURANCE',
#                                                                                     '@required': False,
#                                                                                     'ChildSkill': [{'@existsInText': True,
#                                                                                                     '@id': '019925',
#                                                                                                     '@name': 'INSURANCE '
#                                                                                                              'CLAIMS',
#                                                                                                     '@required': False}]}]},
#                                                                         {'@id': '408',
#                                                                          '@name': 'Claims '
#                                                                                   'and '
#                                                                                   'Adjusting',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 33.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '022237',
#                                                                                     '@name': 'CLAIMS',
#                                                                                     '@required': False}]}]},
#                                                        {'@id': '28',
#                                                         '@name': 'Clinical',
#                                                         '@percentOfOverall': 6.0,
#                                                         'Subtaxonomy': [{'@id': '276',
#                                                                          '@name': 'Tests '
#                                                                                   'and '
#                                                                                   'Functions',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 50.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '023206',
#                                                                                     '@name': 'CALIBRATION',
#                                                                                     '@required': True}]},
#                                                                         {'@id': '269',
#                                                                          '@name': 'Claims '
#                                                                                   'and '
#                                                                                   'Billing',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 50.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '022238',
#                                                                                     '@name': 'CLAIMS',
#                                                                                     '@required': False}]}]},
#                                                        {'@id': '32',
#                                                         '@name': 'Degreed '
#                                                                  'Accounting',
#                                                         '@percentOfOverall': 6.0,
#                                                         'Subtaxonomy': [{'@id': '961',
#                                                                          '@name': 'Payroll',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 50.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '022239',
#                                                                                     '@name': 'CLAIMS',
#                                                                                     '@required': False}]},
#                                                                         {'@id': '933',
#                                                                          '@name': 'Accounts '
#                                                                                   'Payable',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 50.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '013345',
#                                                                                     '@name': 'CLAIMS',
#                                                                                     '@required': False}]}]},
#                                                        {'@id': '20',
#                                                         '@name': 'Sales',
#                                                         '@percentOfOverall': 3.0,
#                                                         'Subtaxonomy': [{'@id': '105',
#                                                                          '@name': 'General',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 100.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '030830',
#                                                                                     '@name': 'SALES '
#                                                                                              'TEAM',
#                                                                                     '@required': False}]}]},
#                                                        {'@id': '80',
#                                                         '@name': 'General '
#                                                                  'Management',
#                                                         '@percentOfOverall': 3.0,
#                                                         'Subtaxonomy': [{'@id': '517',
#                                                                          '@name': 'People '
#                                                                                   'Oriented',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 100.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '009221',
#                                                                                     '@name': 'TEAM '
#                                                                                              'BUILDING',
#                                                                                     '@required': False}]}]},
#                                                        {'@id': '34',
#                                                         '@name': 'Business '
#                                                                  'Operations '
#                                                                  'and General '
#                                                                  'Business',
#                                                         '@percentOfOverall': 3.0,
#                                                         'Subtaxonomy': [{'@id': '437',
#                                                                          '@name': 'General '
#                                                                                   'Skills '
#                                                                                   'and '
#                                                                                   'Activities',
#                                                                          '@percentOfOverall': 3.0,
#                                                                          '@percentOfParentTaxonomy': 100.0,
#                                                                          'Skill': [{'@existsInText': True,
#                                                                                     '@id': '008585',
#                                                                                     '@name': 'STATISTICS',
#                                                                                     '@required': False}]}]}]}],
#                 'SourceText': 'Shift Technology is reinventing insurance '
#                               'claims automation and fraud detection with AI. '
#                               'We help insurers fully automate more claims, '
#                               'deliver a great customer experience while '
#                               'protecting against risk, and accurately '
#                               'identify suspected claims fraud, making '
#                               'investigative teams more effective and reducing '
#                               'fraud losses.\r\n'
#                               '\r\n'
#                               "Since our launch in 2014 in Paris, we've raised "
#                               'over $100M with Tier 1 investors, opened '
#                               'offices in Boston, Tokyo, Singapore, London, '
#                               'Madrid, Zurich, and Hong Kong, and currently '
#                               'work with more than 80 insurers globally. If '
#                               'you are excited about joining a fast-growing '
#                               'insurtech innovator with a passion for '
#                               'excellence and global culture, Shift is the '
#                               'place for you.\r\n'
#                               '\r\n'
#                               'Are you looking for an internship where you can '
#                               'get strong programming skills and discover '
#                               'real-life problems? Come and join the French '
#                               'Insurtech leader to change the insurance world '
#                               'with A.I.!\r\n'
#                               '\r\n'
#                               'This position is for you if you are looking for '
#                               'an end-of-studies internship to complete your '
#                               'degree, and are interested in a permanent '
#                               'position if you think Shift is the right place '
#                               'to start!\r\n'
#                               '\r\n'
#                               'YOUR ROLE\r\n'
#                               '\r\n'
#                               'As a member of the data science team, and '
#                               'working alongside our technical experts, your '
#                               'role will be key to roll-out our different '
#                               'solutions to the clients. Your day-to-day will '
#                               'include :\r\n'
#                               'Set-up and deploy in production the data '
#                               'processing pipelines of our clients, including '
#                               'data reception in batches or in real-time, data '
#                               'cleaning, information extraction, calibration '
#                               'of fraud detection models, etc.\r\n'
#                               'Work closely with our clients to understand '
#                               'their needs, their feedback to improve our '
#                               'solutions\r\n'
#                               'R&D for product development and innovation '
#                               '(through machine learning, image analysis, NLP, '
#                               'trend analysis, chatbots)\r\n'
#                               'Work closely with the sales team for prospects '
#                               'demo (and yes, that includes travelling '
#                               'worldwide!)\r\n'
#                               '\r\n'
#                               'WHAT WE ARE LOOKING FOR\r\n'
#                               "You have a master's degree in mathematics and "
#                               'Statistics, (a knowledge in machine learning '
#                               'and/or Big Data is a plus)\r\n'
#                               'You have experience in object-oriented '
#                               'programming\r\n'
#                               'You combine strong analysis with synthesis '
#                               'abilities and are not afraid to deal with the '
#                               'details\r\n'
#                               'You can write quality production code\r\n'
#                               'You are comfortable dealing with clients\r\n'
#                               'You are fluent in English, and ideally in an '
#                               'other European language\r\n'
#                               'PERKS AND BENEFITS\r\n'
#                               'Nice office in central Paris\r\n'
#                               'International environment (we have more than 35 '
#                               'nationalities represented at Shift!)\r\n'
#                               'Lunch card and public transportation '
#                               'sponsorship\r\n'
#                               'Healthy seasonal basket fruits and cereals\r\n'
#                               'Welcome drinks / Team building events\r\n'
#                               'Workshop and training\r\n'
#                               '\r\n'
#                               'EEO Statement\r\n'
#                               '\r\n'
#                               'At Shift we thrive to be a diverse and '
#                               'inclusive workforce. We hire and trust people '
#                               'without regard to race, color, religion, '
#                               'marital status, age, national or ethnic origin, '
#                               'physical or mental disability, medical '
#                               'condition, pregnancy, genetic information, '
#                               'gender identity or expression, sexual '
#                               'orientation, or other non-merit criteria.\r\n'
#                               'Shift is proud to be an Equal Opportunity '
#                               'Employer.',
#                 'TypeOfSource': 'stJobOrder'},
#  '_id': ObjectId('5e64cbef837ba015d90abc75')}

# %%
file=collection.find()[1]
#Position info
#company_name, position_title, duty_location, position_type,equivalent_grade, language_of_post, source_text
a=file['SovrenData']['EmployerNames']['MainEmployerName']
a=file['SovrenData']['JobTitles']['JobTitle']
a=file['SovrenData']['CurrentLocation']
a=file['SovrenData']['DocumentLanguage']
a=file['SovrenData']['RequiredDegree']
a=file['SovrenData']['SourceText']


#['NonXMLResume'][0]['EducationHistory']#b=file['EducationHistory']['SchoolOrInstitution'][1]['Degree'][0]['DegreeMajor'][0]['Name']




pprint.pprint(a)
#pprint.pprint(b)
# Out:
# ('Shift Technology is reinventing insurance claims automation and fraud '
#  'detection with AI. We help insurers fully automate more claims, deliver a '
#  'great customer experience while protecting against risk, and accurately '
#  'identify suspected claims fraud, making investigative teams more effective '
#  'and reducing fraud losses.\r\n'
#  '\r\n'
#  "Since our launch in 2014 in Paris, we've raised over $100M with Tier 1 "
#  'investors, opened offices in Boston, Tokyo, Singapore, London, Madrid, '
#  'Zurich, and Hong Kong, and currently work with more than 80 insurers '
#  'globally. If you are excited about joining a fast-growing insurtech '
#  'innovator with a passion for excellence and global culture, Shift is the '
#  'place for you.\r\n'
#  '\r\n'
#  'Are you looking for an internship where you can get strong programming '
#  'skills and discover real-life problems? Come and join the French Insurtech '
#  'leader to change the insurance world with A.I.!\r\n'
#  '\r\n'
#  'This position is for you if you are looking for an end-of-studies internship '
#  'to complete your degree, and are interested in a permanent position if you '
#  'think Shift is the right place to start!\r\n'
#  '\r\n'
#  'YOUR ROLE\r\n'
#  '\r\n'
#  'As a member of the data science team, and working alongside our technical '
#  'experts, your role will be key to roll-out our different solutions to the '
#  'clients. Your day-to-day will include :\r\n'
#  'Set-up and deploy in production the data processing pipelines of our '
#  'clients, including data reception in batches or in real-time, data cleaning, '
#  'information extraction, calibration of fraud detection models, etc.\r\n'
#  'Work closely with our clients to understand their needs, their feedback to '
#  'improve our solutions\r\n'
#  'R&D for product development and innovation (through machine learning, image '
#  'analysis, NLP, trend analysis, chatbots)\r\n'
#  'Work closely with the sales team for prospects demo (and yes, that includes '
#  'travelling worldwide!)\r\n'
#  '\r\n'
#  'WHAT WE ARE LOOKING FOR\r\n'
#  "You have a master's degree in mathematics and Statistics, (a knowledge in "
#  'machine learning and/or Big Data is a plus)\r\n'
#  'You have experience in object-oriented programming\r\n'
#  'You combine strong analysis with synthesis abilities and are not afraid to '
#  'deal with the details\r\n'
#  'You can write quality production code\r\n'
#  'You are comfortable dealing with clients\r\n'
#  'You are fluent in English, and ideally in an other European language\r\n'
#  'PERKS AND BENEFITS\r\n'
#  'Nice office in central Paris\r\n'
#  'International environment (we have more than 35 nationalities represented at '
#  'Shift!)\r\n'
#  'Lunch card and public transportation sponsorship\r\n'
#  'Healthy seasonal basket fruits and cereals\r\n'
#  'Welcome drinks / Team building events\r\n'
#  'Workshop and training\r\n'
#  '\r\n'
#  'EEO Statement\r\n'
#  '\r\n'
#  'At Shift we thrive to be a diverse and inclusive workforce. We hire and '
#  'trust people without regard to race, color, religion, marital status, age, '
#  'national or ethnic origin, physical or mental disability, medical condition, '
#  'pregnancy, genetic information, gender identity or expression, sexual '
#  'orientation, or other non-merit criteria.\r\n'
#  'Shift is proud to be an Equal Opportunity Employer.')

# %%
file=collection.find()[1]
ed_code=0
#a=file['EducationHistory']['SchoolOrInstitution'][0]['Degree'][0]['DegreeMajor'][0]['Name']
#b=file['EducationHistory']['SchoolOrInstitution'][1]['Degree'][0]['DegreeMajor'][0]['Name']



pprint.pprint(file)
#pprint.pprint(b)
    

for ed in file['Resume']['StructuredXMLResume']['EducationHistory']['SchoolOrInstitution']: 
    if('Degree' in ed):
        if('@degreeType' in ed['Degree'][0]):
            pprint.pprint('degreeType: '+ ed['Degree'][0]['@degreeType'])
        if('DegreeMajor' in ed['Degree'][0]):
            if('Name' in ed['Degree'][0]['DegreeMajor'][0]):
                pprint.pprint('degreeMajor: '+ed['Degree'][0]['DegreeMajor'][0]['Name'][0])
        if('DatesOfAttendance' in ed['Degree'][0]):
            if('StartDate' in ed['Degree'][0]['DatesOfAttendance'][0]):
                pprint.pprint(ed['Degree'][0]['DatesOfAttendance'][0]['StartDate'])
                
            if('EndDate' in ed['Degree'][0]['DatesOfAttendance'][0]):
                pprint.pprint(ed['Degree'][0]['DatesOfAttendance'][0]['EndDate'])
        if('Comments' in ed['Degree'][0]):
            pprint.pprint(ed['Degree'][0]['Comments'])
    if('School' in ed):
        if('SchoolName' in ed['School'][0]):
            pprint.pprint('SchoolName: '+ed['School'][0]['SchoolName'])
    print("-------------")
# Out:
# {'Resume': {'@xml:lang': 'en',
#             '@xmlns': 'http://ns.hr-xml.org/2006-02-28',
#             '@xmlns:sov': 'http://sovren.com/hr-xml/2006-02-28',
#             'NonXMLResume': {'TextResume': "2/2/20 19'09\r\n"
#                                            '\r\n'
#                                            '\r\n'
#                                            'Annanya Bansal\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'Double post graduate diploma in '
#                                            'Analytics actively looking for '
#                                            'jobs in Data\r\n'
#                                            'Analysis, Data Science, Business '
#                                            'Analysis, Data Integration, Data '
#                                            'Mining, Logistic\r\n'
#                                            'Regression, Machine Learning, '
#                                            'SSIS, SSRS, SQL\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'Current Designation: Data science '
#                                            'Freelancer & Instructor\tTotal '
#                                            'Experience: 0 Year(s) 6 '
#                                            'Month(s)\r\n'
#                                            'Current Location: Delhi\tHighest '
#                                            'Degree: PG Diploma [Business '
#                                            'analytics]\r\n'
#                                            'Pref. Location: Delhi / NCR, '
#                                            'Gurgaon, Noida\r\n'
#                                            'Functional Area: Analytics & '
#                                            'Business Intelligence\r\n'
#                                            'Role: Business Analyst\r\n'
#                                            'Industry: KPO / Research '
#                                            '/Analytics\r\n'
#                                            'Marital Status: Married\r\n'
#                                            'Key Skills: Data Science, Data '
#                                            'Analyst, Data Analysis, Database '
#                                            'Management, Data Analytics, Data '
#                                            'Integration, Data\r\n'
#                                            'Mining, Data Modelling, Data '
#                                            'Extraction, Data Transition, '
#                                            'Logistic Regression, Machine '
#                                            'Learning, Software\r\n'
#                                            'Engineering, SSIS, SSRS, SQL\r\n'
#                                            '\r\n'
#                                            'Verified: Phone Number |\tEmail - '
#                                            'id\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'ID: Last Active: 31-Jan-20\tLast '
#                                            'Modified: 31-Jan-20\r\n'
#                                            'cf4cd182780a4a59833890bc050d361a\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'Summary\r\n'
#                                            'I have done Btech in Computer '
#                                            'Science and also have a double '
#                                            'post graduate diploma in '
#                                            'analytics(Big Data Analytics '
#                                            'from\r\n'
#                                            'CDAC and Business analytics from '
#                                            'IIMK).i have work exposure in Data '
#                                            'Analysis, Database Management, '
#                                            'Data Analytics, Data\r\n'
#                                            'Integration, Data Mining, Data '
#                                            'Modelling, Data Extraction, Data '
#                                            'Transition, Logistic Regression, '
#                                            'Machine Learning, Software\r\n'
#                                            'Engineering, SSIS, SSRS, SQL.\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'Work Experience\r\n'
#                                            'Red Cloud Computing as Software '
#                                            'Engineer\r\n'
#                                            'Aug 2018 to Jan 2019\r\n'
#                                            'Creating Katacoda Scenarios for '
#                                            "Bluedata's clients\r\n"
#                                            'Building customized Docker images '
#                                            'for various Clients.\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'as Data science Freelancer & '
#                                            'Instructor\r\n'
#                                            'Mar 2018 to Till Date\r\n'
#                                            'Providing services and assistance '
#                                            'for data science projects along '
#                                            'with online classes\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'GradeUp as Freelance Content '
#                                            'Developer\r\n'
#                                            'Mar 2017 to Sep 2017\r\n'
#                                            'Developing multiple choice '
#                                            'questions for GATE examination.\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'https://freesearch.naukri.com/preview/printResume?uname=3d2   '
#                                            '090109533a4454405a4d5f0b02546&sid=3810263223&AT=1580666761\r\n'
#                                            "2/2/20 19'09\r\n"
#                                            '\r\n'
#                                            '\r\n'
#                                            'Education\r\n'
#                                            'UG: B.Tech/B.E. (Computers) from '
#                                            'Guru Gobind Singh Indraprastha '
#                                            'University (GGSIU) in 2016\r\n'
#                                            '\r\n'
#                                            'PG: PG Diploma (Business '
#                                            'analytics), '
#                                            'Correspondence/Distance Learning '
#                                            'from Indian Institute of '
#                                            'Management (IIM),\r\n'
#                                            'Kozhikode in 2019\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'IT Skills\r\n'
#                                            'Skill Name\tVersion Last Used\t'
#                                            'Experience\r\n'
#                                            '\r\n'
#                                            'R, Python, Tableau\r\n'
#                                            '\r\n'
#                                            'Rapidminer, Hadoop\r\n'
#                                            '\r\n'
#                                            'Spark, SPSS\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'Affirmative Action\r\n'
#                                            'Physically Challenged: No\r\n'
#                                            '\r\n'
#                                            '\r\n'
#                                            'https://freesearch.naukri.com/preview/printResume?uname=3d2   '
#                                            '090109533a4454405a4d5f0b02546&sid=3810263223&AT=1580666761\r\n'
#                                            'de 2'},
#             'ResumeId': {'IdValue': None},
#             'StructuredXMLResume': {'ContactInfo': {'PersonName': {'FamilyName': 'Bansal',
#                                                                    'FormattedName': 'Annanya '
#                                                                                     'Bansal',
#                                                                    'GivenName': 'Annanya'}},
#                                     'EducationHistory': {'SchoolOrInstitution': [{'@schoolType': 'university',
#                                                                                   'Degree': [{'@degreeType': 'some '
#                                                                                                              'post-graduate',
#                                                                                               'Comments': 'PG: '
#                                                                                                           'PG '
#                                                                                                           'Diploma '
#                                                                                                           '(Business '
#                                                                                                           'analytics), '
#                                                                                                           'Correspondence/Distance '
#                                                                                                           'Learning '
#                                                                                                           'from '
#                                                                                                           'Indian '
#                                                                                                           'Institute '
#                                                                                                           'of '
#                                                                                                           'Management '
#                                                                                                           '(IIM),\r\n'
#                                                                                                           'Kozhikode '
#                                                                                                           'in '
#                                                                                                           '2019',
#                                                                                               'DatesOfAttendance': [{'EndDate': {'Year': '2019'},
#                                                                                                                      'StartDate': {'AnyDate': 'notKnown'}}],
#                                                                                               'DegreeDate': {'Year': '2019'},
#                                                                                               'DegreeMajor': [{'Name': ['Business']}],
#                                                                                               'DegreeName': 'PG '
#                                                                                                             'Diploma',
#                                                                                               'UserArea': {'sov:DegreeUserArea': {'sov:Id': 'DEG-2',
#                                                                                                                                   'sov:NormalizedDegreeName': 'somepostgraduate',
#                                                                                                                                   'sov:NormalizedDegreeType': 'some '
#                                                                                                                                                               'post-graduate'}}}],
#                                                                                   'School': [{'SchoolName': 'Indian '
#                                                                                                             'Institute '
#                                                                                                             'of '
#                                                                                                             'Management '
#                                                                                                             '(IIM)'}],
#                                                                                   'UserArea': {'sov:SchoolOrInstitutionTypeUserArea': {'sov:NormalizedSchoolName': 'Indian '
#                                                                                                                                                                    'Institute '
#                                                                                                                                                                    'of '
#                                                                                                                                                                    'Management '
#                                                                                                                                                                    'IIM'}}},
#                                                                                  {'@schoolType': 'university',
#                                                                                   'Degree': [{'@degreeType': 'bachelors',
#                                                                                               'Comments': 'UG: '
#                                                                                                           'B.Tech/B.E. '
#                                                                                                           '(Computers) '
#                                                                                                           'from '
#                                                                                                           'Guru '
#                                                                                                           'Gobind '
#                                                                                                           'Singh '
#                                                                                                           'Indraprastha '
#                                                                                                           'University '
#                                                                                                           '(GGSIU) '
#                                                                                                           'in '
#                                                                                                           '2016',
#                                                                                               'DatesOfAttendance': [{'EndDate': {'Year': '2016'},
#                                                                                                                      'StartDate': {'AnyDate': 'notKnown'}}],
#                                                                                               'DegreeDate': {'Year': '2016'},
#                                                                                               'DegreeMajor': [{'Name': ['Computers']}],
#                                                                                               'DegreeName': 'B.Tech/B.E.',
#                                                                                               'UserArea': {'sov:DegreeUserArea': {'sov:Id': 'DEG-1',
#                                                                                                                                   'sov:NormalizedDegreeName': 'bachelors',
#                                                                                                                                   'sov:NormalizedDegreeType': 'bachelors'}}}],
#                                                                                   'School': [{'SchoolName': 'Guru '
#                                                                                                             'Gobind '
#                                                                                                             'Singh '
#                                                                                                             'Indraprastha '
#                                                                                                             'University'}],
#                                                                                   'UserArea': {'sov:SchoolOrInstitutionTypeUserArea': {'sov:NormalizedSchoolName': 'Guru '
#                                                                                                                                                                    'Gobind '
#                                                                                                                                                                    'Singh '
#                                                                                                                                                                    'Indraprastha '
#                                                                                                                                                                    'University'}}}]},
#                                     'EmploymentHistory': {'EmployerOrg': [{'EmployerOrgName': '',
#                                                                            'PositionHistory': [{'@currentEmployer': 'true',
#                                                                                                 '@positionType': 'contract',
#                                                                                                 'Description': 'Providing '
#                                                                                                                'services '
#                                                                                                                'and '
#                                                                                                                'assistance '
#                                                                                                                'for '
#                                                                                                                'data '
#                                                                                                                'science '
#                                                                                                                'projects '
#                                                                                                                'along '
#                                                                                                                'with '
#                                                                                                                'online '
#                                                                                                                'classes',
#                                                                                                 'EndDate': {'StringDate': 'current'},
#                                                                                                 'JobCategory': [{'CategoryCode': 'Information '
#                                                                                                                                  'Technology '
#                                                                                                                                  '→ '
#                                                                                                                                  'Machine '
#                                                                                                                                  'Learning',
#                                                                                                                  'Comments': 'Information '
#                                                                                                                              'Technology '
#                                                                                                                              'describes '
#                                                                                                                              '100% '
#                                                                                                                              'of '
#                                                                                                                              'this '
#                                                                                                                              'job',
#                                                                                                                  'TaxonomyName': 'Skills '
#                                                                                                                                  'taxonomy'},
#                                                                                                                 {'CategoryCode': 'Experienced '
#                                                                                                                                  '(non-manager)',
#                                                                                                                  'TaxonomyName': 'Job '
#                                                                                                                                  'Level'}],
#                                                                                                 'OrgName': {'OrganizationName': None},
#                                                                                                 'StartDate': {'YearMonth': '2018-03'},
#                                                                                                 'Title': 'Data '
#                                                                                                          'science '
#                                                                                                          'Freelancer '
#                                                                                                          '& '
#                                                                                                          'Instructor',
#                                                                                                 'UserArea': {'sov:PositionHistoryUserArea': {'sov:Id': 'POS-2',
#                                                                                                                                              'sov:NormalizedTitle': 'Data '
#                                                                                                                                                                     'science '
#                                                                                                                                                                     'Freelancer '
#                                                                                                                                                                     'AND '
#                                                                                                                                                                     'Instructor',
#                                                                                                                                              'sov:PositionTitleProbabilityInterpretation': {'#text': 'Confident',
#                                                                                                                                                                                             '@internalUseOnly': 'SS'},
#                                                                                                                                              'sov:Subtitles': {'sov:Subtitle': ['Freelancer '
#                                                                                                                                                                                 '& '
#                                                                                                                                                                                 'Instructor']}}}}]},
#                                                                           {'EmployerOrgName': 'Red '
#                                                                                               'Cloud '
#                                                                                               'Computing',
#                                                                            'PositionHistory': [{'@positionType': 'directHire',
#                                                                                                 'Description': 'Creating '
#                                                                                                                'Katacoda '
#                                                                                                                'Scenarios '
#                                                                                                                'for '
#                                                                                                                "Bluedata's "
#                                                                                                                'clients\r\n'
#                                                                                                                'Building '
#                                                                                                                'customized '
#                                                                                                                'Docker '
#                                                                                                                'images '
#                                                                                                                'for '
#                                                                                                                'various '
#                                                                                                                'Clients.',
#                                                                                                 'EndDate': {'YearMonth': '2019-01'},
#                                                                                                 'JobCategory': [{'CategoryCode': 'Information '
#                                                                                                                                  'Technology '
#                                                                                                                                  '→ '
#                                                                                                                                  'Programming',
#                                                                                                                  'Comments': 'Information '
#                                                                                                                              'Technology '
#                                                                                                                              'describes '
#                                                                                                                              '50% '
#                                                                                                                              'of '
#                                                                                                                              'this '
#                                                                                                                              'job',
#                                                                                                                  'TaxonomyName': 'Skills '
#                                                                                                                                  'taxonomy'},
#                                                                                                                 {'CategoryCode': 'Experienced '
#                                                                                                                                  '(non-manager)',
#                                                                                                                  'TaxonomyName': 'Job '
#                                                                                                                                  'Level'}],
#                                                                                                 'OrgName': {'OrganizationName': 'Red '
#                                                                                                                                 'Cloud '
#                                                                                                                                 'Computing'},
#                                                                                                 'StartDate': {'YearMonth': '2018-08'},
#                                                                                                 'Title': 'Software '
#                                                                                                          'Engineer',
#                                                                                                 'UserArea': {'sov:PositionHistoryUserArea': {'sov:CompanyNameProbabilityInterpretation': {'#text': 'Probable',
#                                                                                                                                                                                           '@internalUseOnly': 'X'},
#                                                                                                                                              'sov:Id': 'POS-1',
#                                                                                                                                              'sov:NormalizedOrganizationName': 'Red '
#                                                                                                                                                                                'Cloud '
#                                                                                                                                                                                'Computing',
#                                                                                                                                              'sov:NormalizedTitle': 'Software '
#                                                                                                                                                                     'Engineer',
#                                                                                                                                              'sov:PositionTitleProbabilityInterpretation': {'#text': 'Confident',
#                                                                                                                                                                                             '@internalUseOnly': 'SQ'}}}}],
#                                                                            'UserArea': {'sov:EmployerOrgUserArea': {'sov:NormalizedEmployerOrgName': 'Red '
#                                                                                                                                                      'Cloud '
#                                                                                                                                                      'Computing'}}},
#                                                                           {'EmployerOrgName': '',
#                                                                            'PositionHistory': [{'@positionType': 'contract',
#                                                                                                 'Description': 'Developing '
#                                                                                                                'multiple '
#                                                                                                                'choice '
#                                                                                                                'questions '
#                                                                                                                'for '
#                                                                                                                'GATE '
#                                                                                                                'examination.',
#                                                                                                 'EndDate': {'YearMonth': '2017-09'},
#                                                                                                 'JobCategory': [{'CategoryCode': 'Entry '
#                                                                                                                                  'Level',
#                                                                                                                  'TaxonomyName': 'Job '
#                                                                                                                                  'Level'}],
#                                                                                                 'OrgName': {'OrganizationName': None},
#                                                                                                 'StartDate': {'YearMonth': '2017-03'},
#                                                                                                 'Title': 'Freelance '
#                                                                                                          'Content '
#                                                                                                          'Developer',
#                                                                                                 'UserArea': {'sov:PositionHistoryUserArea': {'sov:Id': 'POS-3',
#                                                                                                                                              'sov:IsSelfEmployed': 'true',
#                                                                                                                                              'sov:NormalizedTitle': 'Freelance '
#                                                                                                                                                                     'Content '
#                                                                                                                                                                     'Developer',
#                                                                                                                                              'sov:PositionTitleProbabilityInterpretation': {'#text': 'Confident',
#                                                                                                                                                                                             '@internalUseOnly': 'SQ'},
#                                                                                                                                              'sov:SelfEmploymentPhrase': 'Freelance'}}}]}]},
#                                     'ExecutiveSummary': 'I have done Btech in '
#                                                         'Computer Science and '
#                                                         'also have a double '
#                                                         'post graduate diploma '
#                                                         'in analytics(Big Data '
#                                                         'Analytics from\r\n'
#                                                         'CDAC and Business '
#                                                         'analytics from '
#                                                         'IIMK).i have work '
#                                                         'exposure in Data '
#                                                         'Analysis, Database '
#                                                         'Management, Data '
#                                                         'Analytics, Data\r\n'
#                                                         'Integration, Data '
#                                                         'Mining, Data '
#                                                         'Modelling, Data '
#                                                         'Extraction, Data '
#                                                         'Transition, Logistic '
#                                                         'Regression, Machine '
#                                                         'Learning, Software\r\n'
#                                                         'Engineering, SSIS, '
#                                                         'SSRS, SQL.',
#                                     'Languages': {'Language': [{'Comments': '[RESUME_LANGUAGE]',
#                                                                 'LanguageCode': 'en',
#                                                                 'Read': 'true',
#                                                                 'Speak': 'true',
#                                                                 'Write': 'true'}]},
#                                     'Qualifications': {'QualificationSummary': 'Key '
#                                                                                'Skills: '
#                                                                                'Data '
#                                                                                'Science, '
#                                                                                'Data '
#                                                                                'Analyst, '
#                                                                                'Data '
#                                                                                'Analysis, '
#                                                                                'Database '
#                                                                                'Management, '
#                                                                                'Data '
#                                                                                'Analytics, '
#                                                                                'Data '
#                                                                                'Integration, '
#                                                                                'Data\r\n'
#                                                                                'Mining, '
#                                                                                'Data '
#                                                                                'Modelling, '
#                                                                                'Data '
#                                                                                'Extraction, '
#                                                                                'Data '
#                                                                                'Transition, '
#                                                                                'Logistic '
#                                                                                'Regression, '
#                                                                                'Machine '
#                                                                                'Learning, '
#                                                                                'Software\r\n'
#                                                                                'Engineering, '
#                                                                                'SSIS, '
#                                                                                'SSRS, '
#                                                                                'SQL\r\n'
#                                                                                '\r\n'
#                                                                                'Verified: '
#                                                                                'Phone '
#                                                                                'Number '
#                                                                                '|\t'
#                                                                                'Email '
#                                                                                '- '
#                                                                                'id\r\n'
#                                                                                '\r\n'
#                                                                                '\r\n'
#                                                                                'ID: '
#                                                                                'Last '
#                                                                                'Active: '
#                                                                                '31-Jan-20\t'
#                                                                                'Last '
#                                                                                'Modified: '
#                                                                                '31-Jan-20\r\n'
#                                                                                'cf4cd182780a4a59833890bc050d361a\r\n'
#                                                                                '\r\n'
#                                                                                '\r\n'
#                                                                                'IT '
#                                                                                'Skills\r\n'
#                                                                                'Skill '
#                                                                                'Name\t'
#                                                                                'Version '
#                                                                                'Last '
#                                                                                'Used\t'
#                                                                                'Experience\r\n'
#                                                                                '\r\n'
#                                                                                'R, '
#                                                                                'Python, '
#                                                                                'Tableau\r\n'
#                                                                                '\r\n'
#                                                                                'Rapidminer, '
#                                                                                'Hadoop\r\n'
#                                                                                '\r\n'
#                                                                                'Spark, '
#                                                                                'SPSS\r\n'
#                                                                                '\r\n'
#                                                                                '\r\n'
#                                                                                'Affirmative '
#                                                                                'Action\r\n'
#                                                                                'Physically '
#                                                                                'Challenged: '
#                                                                                'No\r\n'
#                                                                                '\r\n'
#                                                                                '\r\n'
#                                                                                'https://freesearch.naukri.com/preview/printResume?uname=3d2   '
#                                                                                '090109533a4454405a4d5f0b02546&sid=3810263223&AT=1580666761\r\n'
#                                                                                'de '
#                                                                                '2'},
#                                     'RevisionDate': '2020-02-03'},
#             'UserArea': {'sov:ResumeUserArea': {'sov:Culture': {'sov:Country': 'US',
#                                                                 'sov:CultureInfo': 'en-US',
#                                                                 'sov:Language': 'en'},
#                                                 'sov:DigitalSignature': 'qgn///////8=',
#                                                 'sov:ExperienceSummary': {'sov:AverageMonthsPerEmployer': '10',
#                                                                           'sov:Description': 'Annanya '
#                                                                                              "Bansal's "
#                                                                                              'experience '
# ...
#                                                                                                                                                    'as '
#                                                                                                                                                    'a '
#                                                                                                                                                    'skills '
#                                                                                                                                                    'section '
#                                                                                                                                                    'type: '
#                                                                                                                                                    "'Key "
#                                                                                                                                                    "Skills', "
#                                                                                                                                                    "'IT "
#                                                                                                                                                    "Skills'. "
#                                                                                                                                                    'Skills '
#                                                                                                                                                    'should '
#                                                                                                                                                    'not '
#                                                                                                                                                    'be '
#                                                                                                                                                    'in '
#                                                                                                                                                    'a '
#                                                                                                                                                    'separate '
#                                                                                                                                                    'section, '
#                                                                                                                                                    'but '
#                                                                                                                                                    'instead, '
#                                                                                                                                                    'each '
#                                                                                                                                                    'skill '
#                                                                                                                                                    'should '
#                                                                                                                                                    'be '
#                                                                                                                                                    'included '
#                                                                                                                                                    'in '
#                                                                                                                                                    'the '
#                                                                                                                                                    'descriptions '
#                                                                                                                                                    'of '
#                                                                                                                                                    'work '
#                                                                                                                                                    'history '
#                                                                                                                                                    'or '
#                                                                                                                                                    'education.',
#                                                                                                                                                    '[Sovren:123;] '
#                                                                                                                                                    'Marital '
#                                                                                                                                                    'status '
#                                                                                                                                                    'should '
#                                                                                                                                                    'not '
#                                                                                                                                                    'be '
#                                                                                                                                                    'included '
#                                                                                                                                                    'in '
#                                                                                                                                                    'a '
#                                                                                                                                                    'resume '
#                                                                                                                                                    '(for '
#                                                                                                                                                    'most '
#                                                                                                                                                    'cultures).',
#                                                                                                                                                    '[Sovren:151;0] '
#                                                                                                                                                    'The '
#                                                                                                                                                    'following '
#                                                                                                                                                    'section '
#                                                                                                                                                    'does '
#                                                                                                                                                    'not '
#                                                                                                                                                    'have '
#                                                                                                                                                    'the '
#                                                                                                                                                    'header '
#                                                                                                                                                    'on '
#                                                                                                                                                    'a '
#                                                                                                                                                    'separate '
#                                                                                                                                                    'line: '
#                                                                                                                                                    "'Key "
#                                                                                                                                                    "Skills'. "
#                                                                                                                                                    'Every '
#                                                                                                                                                    'section '
#                                                                                                                                                    'should '
#                                                                                                                                                    'have '
#                                                                                                                                                    'a '
#                                                                                                                                                    'clear, '
#                                                                                                                                                    'unambiguous, '
#                                                                                                                                                    'commonly-used '
#                                                                                                                                                    'header '
#                                                                                                                                                    'on '
#                                                                                                                                                    'a '
#                                                                                                                                                    'separate '
#                                                                                                                                                    'line '
#                                                                                                                                                    'directly '
#                                                                                                                                                    'above '
#                                                                                                                                                    'the '
#                                                                                                                                                    'content '
#                                                                                                                                                    'associated '
#                                                                                                                                                    'with '
#                                                                                                                                                    'it.']},
#                                                                                                               'sov:Level': 'Suggested '
#                                                                                                                            'Improvements'}]}},
#                                                 'sov:Sections': {'sov:Section': [{'#text': 'Key '
#                                                                                            'Skills',
#                                                                                   '@ends': '28',
#                                                                                   '@sectionType': 'SKILLS',
#                                                                                   '@starts': '18'},
#                                                                                  {'#text': 'Summary',
#                                                                                   '@ends': '35',
#                                                                                   '@sectionType': 'SUMMARY',
#                                                                                   '@starts': '29'},
#                                                                                  {'#text': 'Work '
#                                                                                            'Experience',
#                                                                                   '@ends': '56',
#                                                                                   '@sectionType': 'WORK '
#                                                                                                   'HISTORY',
#                                                                                   '@starts': '36'},
#                                                                                  {'#text': 'Education',
#                                                                                   '@ends': '63',
#                                                                                   '@sectionType': 'EDUCATION',
#                                                                                   '@starts': '57'},
#                                                                                  {'#text': 'IT '
#                                                                                            'Skills',
#                                                                                   '@ends': '79',
#                                                                                   '@sectionType': 'SKILLS',
#                                                                                   '@starts': '64'}]}}}},
#  '_id': ObjectId('5e60f5895a90883323e38bbd')}
# 'degreeType: some post-graduate'
# 'degreeMajor: Business'
# {'AnyDate': 'notKnown'}
# {'Year': '2019'}
# ('PG: PG Diploma (Business analytics), Correspondence/Distance Learning from '
#  'Indian Institute of Management (IIM),\r\n'
#  'Kozhikode in 2019')
# 'SchoolName: Indian Institute of Management (IIM)'
# -------------
# 'degreeType: bachelors'
# 'degreeMajor: Computers'
# {'AnyDate': 'notKnown'}
# {'Year': '2016'}
# ('UG: B.Tech/B.E. (Computers) from Guru Gobind Singh Indraprastha University '
#  '(GGSIU) in 2016')
# 'SchoolName: Guru Gobind Singh Indraprastha University'
# -------------

# %%
file=collection.find()[0]

candidate_info_list = []
education_list = []
experience_list = []

#Candidate_info
candidate_id =file['Code']
candidate_name =file['PersonName']['FormattedName']
#years_exp = 

#Education_info
row_id=i
career_name=
school_name=
level_education=
start_year=
end_year=
candidate_id=

#Experience



#import pprint
#for file in collection.find():
#    "pprint.pprint(file)"
#    print(file['ContactInfo']['PersonName']['FormattedName'])
#    pause()

# %%
import pandas as pd
import numpy as np

# %%
#Creating education table
education_list = []

for file in collection.find():
    if('EducationHistory' in file['Resume']['StructuredXMLResume']):
        for ed in file['Resume']['StructuredXMLResume']['EducationHistory']['SchoolOrInstitution']: 
            candidate_id=level_education=career_name=start_year=end_year=degree_comments=school_name=''
            candidate_id=file['_id'] #FK
            if('Degree' in ed):
                if('@degreeType' in ed['Degree'][0]):
                    #pprint.pprint('degreeType: '+ ed['Degree'][0]['@degreeType'])
                    level_education=ed['Degree'][0]['@degreeType']

                if('DegreeMajor' in ed['Degree'][0]):
                    if('Name' in ed['Degree'][0]['DegreeMajor'][0]):
                        #pprint.pprint('degreeMajor: '+ed['Degree'][0]['DegreeMajor'][0]['Name'][0])
                        career_name=ed['Degree'][0]['DegreeMajor'][0]['Name'][0]

                if('DatesOfAttendance' in ed['Degree'][0]):
                    if('StartDate' in ed['Degree'][0]['DatesOfAttendance'][0]):
                        #pprint.pprint(ed['Degree'][0]['DatesOfAttendance'][0]['StartDate'])
                        start_year=ed['Degree'][0]['DatesOfAttendance'][0]['StartDate']

                    if('EndDate' in ed['Degree'][0]['DatesOfAttendance'][0]):
                        #pprint.pprint(ed['Degree'][0]['DatesOfAttendance'][0]['EndDate'])
                        end_year=ed['Degree'][0]['DatesOfAttendance'][0]['EndDate']

                if('Comments' in ed['Degree'][0]):
                    #pprint.pprint(ed['Degree'][0]['Comments'])
                    degree_comments=ed['Degree'][0]['Comments']

            if('School' in ed):
                if('SchoolName' in ed['School'][0]):
                    #pprint.pprint('SchoolName: '+ed['School'][0]['SchoolName'])
                    school_name=ed['School'][0]['SchoolName']

            #print("-------------")
            education_list.append([candidate_id,level_education,career_name,school_name,start_year,end_year,degree_comments])

# %%
df = pd.DataFrame(education_list, columns=['candidate_id','level_education','career_name','school_name','start_year','end_year','degree_comments'])
df
# Out:
#                  candidate_id     level_education             career_name  \
# 0    5e60f5895a90883323e38bbb           bachelors  information technology
# 1    5e60f5895a90883323e38bbb  some post-graduate  information technology
# 2    5e60f5895a90883323e38bbc           bachelors               Computers
# 3    5e60f5895a90883323e38bbd  some post-graduate                Business
# 4    5e60f5895a90883323e38bbd           bachelors               Computers
# ..                        ...                 ...                     ...
# 169  5e60ffff5a90883323e38c30           bachelors             Electronics
# 170  5e60ffff5a90883323e38c30  some post-graduate             Electronics
# 171  5e60ffff5a90883323e38c31             masters               Marketing
# 172  5e60ffff5a90883323e38c31           bachelors              Management
# 173  5e60ffff5a90883323e38c32           bachelors               Computers
#
#                                      school_name                 start_year  \
# 0                              Mumbai University    {'AnyDate': 'notKnown'}
# 1                              Mumbai University    {'AnyDate': 'notKnown'}
# 2    Jaypee University of Information Technology    {'AnyDate': 'notKnown'}
# 3           Indian Institute of Management (IIM)    {'AnyDate': 'notKnown'}
# 4      Guru Gobind Singh Indraprastha University    {'AnyDate': 'notKnown'}
# ..                                           ...                        ...
# 169               Siksha O Anusandhan University  {'AnyDate': '2020-02-02'}
# 170               SIKSHA O ANUSANDHAN UNIVERSITY    {'AnyDate': 'notKnown'}
# 171                       Indus Business Academy    {'AnyDate': 'notKnown'}
# 172                           Osmania University    {'AnyDate': 'notKnown'}
# 173      Nitte Meenakshi Institute of Technology    {'AnyDate': 'notKnown'}
#
#              end_year                                    degree_comments
# 0    {'Year': '2017'}  UG: B.Sc (information technology) from Mumbai ...
# 1    {'Year': '2017'}  Post PG: BSC (information technology) from Mum...
# 2    {'Year': '2018'}  UG: B.Tech/B.E. (Computers) from Jaypee Univer...
# 3    {'Year': '2019'}  PG: PG Diploma (Business analytics), Correspon...
# 4    {'Year': '2016'}  UG: B.Tech/B.E. (Computers) from Guru Gobind S...
# ..                ...                                                ...
# 169  {'Year': '2023'}  https://freesearch.naukri.com/preview/printRes...
# 170  {'Year': '2018'}  PG: M.Tech (Electronics/Telecommunication) fro...
# 171  {'Year': '2017'}  PG: MBA/PGDM (Marketing) from Indus Business A...
# 172  {'Year': '2015'}  UG: B.B.A/ B.M.S (Management) from Osmania Uni...
# 173  {'Year': '2018'}  UG: B.Tech/B.E. (Computers) from Nitte Meenaks...
#
# [174 rows x 7 columns]

# %%
#Creating experience table
#CandidateID
#EmployerOrgName
#@positionType
#Title
#Description
#StartDate
#EndDate


file=collection.find()[2]
ed_code=0
#a=file['EducationHistory']['SchoolOrInstitution'][0]['Degree'][0]['DegreeMajor'][0]['Name']
#b=file['EducationHistory']['SchoolOrInstitution'][1]['Degree'][0]['DegreeMajor'][0]['Name']



#pprint.pprint(file)
#pprint.pprint(b)
    

for ed in file['Resume']['StructuredXMLResume']['EmploymentHistory']['EmployerOrg']: 
    if('OrgName' in ed['PositionHistory'][0]):
        pprint.pprint(ed['PositionHistory'][0]['OrgName']['OrganizationName'])
    if('@positionType' in ed['PositionHistory'][0]):
        pprint.pprint(ed['PositionHistory'][0]['@positionType'])
    if('Title' in ed['PositionHistory'][0]):
        pprint.pprint(ed['PositionHistory'][0]['Title'])
    if('Description' in ed['PositionHistory'][0]):
        pprint.pprint(ed['PositionHistory'][0]['Description'])
    if('StartDate' in ed['PositionHistory'][0]):
        pprint.pprint(ed['PositionHistory'][0]['StartDate'])
    if('EndDate' in ed['PositionHistory'][0]):
        pprint.pprint(ed['PositionHistory'][0]['StartDate'])
    print("-------------")
# Out:
# None
# 'contract'
# 'Data science Freelancer & Instructor'
# ('Providing services and assistance for data science projects along with '
#  'online classes')
# {'YearMonth': '2018-03'}
# {'YearMonth': '2018-03'}
# -------------
# 'Red Cloud Computing'
# 'directHire'
# 'Software Engineer'
# ("Creating Katacoda Scenarios for Bluedata's clients\r\n"
#  'Building customized Docker images for various Clients.')
# {'YearMonth': '2018-08'}
# {'YearMonth': '2018-08'}
# -------------
# None
# 'contract'
# 'Freelance Content Developer'
# 'Developing multiple choice questions for GATE examination.'
# {'YearMonth': '2017-03'}
# {'YearMonth': '2017-03'}
# -------------

# %%
for i in range(0,10):
    val0 = 1  # some formula for obtaining values
    val1 = 2.5
    val2 = 1.8
    myList.append([val0,val1,val2])

df = pd.DataFrame(myList, columns=['val0','val1','val2'])
print(df)

# %%
from pymongo import MongoClient
from random import randint
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient(port=27017)
db=client.business
#Step 2: Create sample data
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']
for x in range(1, 501):
    business = {
        'name' : names[randint(0, (len(names)-1))] + ' ' + names[randint(0, (len(names)-1))]  + ' ' + company_type[randint(0, (len(company_type)-1))],
        'rating' : randint(1, 5),
        'cuisine' : company_cuisine[randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via isnert_one
    result=db.reviews.insert_one(business)
    #Step 4: Print to the console the ObjectID of the new document
    print('Created {0} of 500 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
